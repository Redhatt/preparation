# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1024
a = np.random.exponential(100, n)
f = np.fft.fft(a)
mf = abs(f)
print("max at", np.argmax(mf))
plt.plot(np.abs(f))
# Out:
# max at 0
